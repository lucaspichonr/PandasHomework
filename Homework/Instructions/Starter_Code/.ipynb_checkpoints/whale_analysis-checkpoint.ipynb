# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_csv = Path("../Starter_Code/Resources/whale_returns.csv")
whale_df = pd.read_csv(whale_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace=True)
whale_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_csv = Path("../Starter_Code/Resources/algo_returns.csv")
algo_df = pd.read_csv(algo_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
algo_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df.dropna(inplace=True)
algo_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp_csv = Path("../Starter_Code/Resources/sp500_history.csv")
sp_df = pd.read_csv(sp_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
sp_df.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
sp_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp_df['Close'] = sp_df['Close'].str.replace('$','')
sp_df["Close"] = pd.to_numeric(sp_df["Close"])
sp_df
# Out:
# <ipython-input-10-e643791545fb>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   sp_df['Close'] = sp_df['Close'].str.replace('$','')
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06
# ...             ...
# 2012-10-05  1460.93
# 2012-10-04  1461.40
# 2012-10-03  1450.99
# 2012-10-02  1445.75
# 2012-10-01  1444.49
#
# [1649 rows x 1 columns]

# %%
sp_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
sp_returns = sp_df.pct_change()
sp_returns
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1649 rows x 1 columns]

# %%
# Drop nulls
sp_returns.dropna(inplace=True)
sp_returns
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_returns.columns =['SP500 Returns']
sp_returns
# Out:
#             SP500 Returns
# Date
# 2019-04-22      -0.008764
# 2019-04-18      -0.001011
# 2019-04-17      -0.001577
# 2019-04-16       0.002279
# 2019-04-15      -0.000509
# ...                   ...
# 2012-10-05       0.003469
# 2012-10-04       0.000322
# 2012-10-03      -0.007123
# 2012-10-02      -0.003611
# 2012-10-01      -0.000872
#
# [1648 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_df = pd.concat([whale_df, algo_df, sp_returns], axis="columns", join="inner")
combined_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + combined_df).cumprod() - 1
cumulative_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.000962           -0.001755
# 2015-03-05                   0.004981            0.002314
# 2015-03-06                  -0.002963           -0.001269
# 2015-03-09                  -0.002383            0.002951
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.003028               -0.002383 -0.010514
# 2015-03-05                    -0.000681                0.004327 -0.011459
# 2015-03-06                    -0.009156               -0.008828 -0.016359
# 2015-03-09                    -0.003367               -0.010466 -0.021717
#
#               Algo 2  SP500 Returns
# Date
# 2015-03-03 -0.000949       0.004408
# 2015-03-04  0.001464       0.003208
# 2015-03-05  0.005794       0.017632
# ...

# %%
# Plot cumulative returns
cumulative_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
cumulative_returns.boxplot(fontsize = 10, rot = 45, figsize = (20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
combined_df.std().plot(fontsize = 10, rot = 45, figsize = (20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp_daily_std = sp_returns.std()
sp_daily_std
# Out:
# SP500 Returns    0.008135
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P 500
print('Tiger Global Management LLC and Berkshire Hathaway Inc are riskier than the S&P500')
# Out:
# Tiger Global Management LLC and Berkshire Hathaway Inc are riskier than the S&P500

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
sp_returns.rolling(window=252).std()
# Out:
#             SP500 Returns
# Date
# 2019-04-22            NaN
# 2019-04-18            NaN
# 2019-04-17            NaN
# 2019-04-16            NaN
# 2019-04-15            NaN
# ...                   ...
# 2012-10-05       0.007429
# 2012-10-04       0.007430
# 2012-10-03       0.007396
# 2012-10-02       0.007376
# 2012-10-01       0.007365
#
# [1648 rows x 1 columns]

# %%
sp_returns.rolling(window=252).std().plot(fontsize = 10, rot = 45, figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P 500 using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_df21 = combined_df.rolling(window=21).std()
combined_df21.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                        NaN                 NaN
# 2015-03-05                        NaN                 NaN
# 2015-03-06                        NaN                 NaN
# 2015-03-09                        NaN                 NaN
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN     NaN
# 2015-03-04                          NaN                     NaN     NaN
# 2015-03-05                          NaN                     NaN     NaN
# 2015-03-06                          NaN                     NaN     NaN
# 2015-03-09                          NaN                     NaN     NaN
#
#             Algo 2  SP500 Returns
# Date
# 2015-03-03     NaN            NaN
# 2015-03-04     NaN            NaN
# 2015-03-05     NaN            NaN
# ...

# %%
# Plot the rolling standard deviation
combined_df.rolling(window=21).std().plot(fontsize = 10, rot = 45, figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
combined_df_correlation = combined_df.corr()
# Display de correlation matrix
sns.heatmap(combined_df_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance_soros = combined_df['SOROS FUND MANAGEMENT LLC'].cov(combined_df['SP500 Returns'])
covariance_soros
# Out:
# 3.889726983061925e-08

# %%
# Calculate variance of S&P 500
variance_sp500 = combined_df['SP500 Returns'].var()
variance_sp500
# Out:
# 7.373467552840441e-05

# %%
# Computing beta
soros_beta = covariance_soros / variance_sp500
soros_beta
# Out:
# 0.000527530223085271

# %%
rolling_covariance_soros = combined_df['SOROS FUND MANAGEMENT LLC'].rolling(window=60).cov(combined_df['SP500 Returns'])
rolling_covariance_soros.plot(figsize=(20, 10), title='Rolling 60-Day Covariance of SOROS FUND MANAGEMENT LLC Returns vs. S&P 500 Returns')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Covariance of SOROS FUND MANAGEMENT LLC Returns vs. S&P 500 Returns'}, xlabel='Date'>

# %%
rolling_variance_sp500 = combined_df['SP500 Returns'].rolling(window=60).var()
rolling_variance_sp500.plot(figsize=(20, 10), title='Rolling 60-Day Variance of S&P 500 Returns')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Variance of S&P 500 Returns'}, xlabel='Date'>

# %%
# Plot beta trend
rolling_beta_soros = rolling_covariance_soros / rolling_variance_sp500
rolling_beta_soros.plot(figsize=(20, 10), title='Rolling 60-Day Beta of SOROS FUND MANAGEMENT LLC')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of SOROS FUND MANAGEMENT LLC'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
combined_df.ewm(halflife = 21)
# Out:
# ExponentialMovingWindow [com=29.799346392775035,min_periods=1,adjust=True,ignore_na=False,axis=0]

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_df.mean() * 252) / (combined_df.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# SP500 Returns                 -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind= 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %%
print('algorithmic portfolios have outperformed the S&P 500. Algo 1 has outperformed all whale portfolios while Algo 2 outperformed all whale portfolios except Berkshire Hathaway Inc')
# Out:
# algorithmic portfolios have outperformed the S&P 500. Algo 1 has outperformed all whale portfolios while Algo 2 outperformed all whale portfolios except Berkshire Hathaway Inc

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock
goog_csv = Path("../Starter_Code/Resources/goog_historical.csv")
goog_df = pd.read_csv(goog_csv, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
goog_df.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
# Reading data from 2nd stock
aapl_csv = Path("../Starter_Code/Resources/aapl_historical.csv")
aapl_df = pd.read_csv(aapl_csv, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
aapl_df.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75

# %%
# Reading data from 3rd stock
cost_csv = Path("../Starter_Code/Resources/cost_historical.csv")
cost_df = pd.read_csv(cost_csv, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
cost_df.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62

# %%
# Combine all stocks in a single DataFrame
combined_stocks_df = pd.concat([goog_df, aapl_df, cost_df], axis="columns", join="inner")
combined_stocks_df.head()
# Out:
#            Symbol     NOCP Symbol    NOCP Symbol    NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38   AAPL  200.72   COST  243.47
# 2019-05-08   GOOG  1166.27   AAPL  202.90   COST  241.34
# 2019-05-07   GOOG  1174.10   AAPL  202.86   COST  240.18
# 2019-05-06   GOOG  1189.39   AAPL  208.48   COST  244.23
# 2019-05-03   GOOG  1185.40   AAPL  211.75   COST  244.62

# %%
# Reset Date index
combined_stocks_df.reset_index()
combined_stocks_df.head()
# Out:
#            Symbol     NOCP Symbol    NOCP Symbol    NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38   AAPL  200.72   COST  243.47
# 2019-05-08   GOOG  1166.27   AAPL  202.90   COST  241.34
# 2019-05-07   GOOG  1174.10   AAPL  202.86   COST  240.18
# 2019-05-06   GOOG  1189.39   AAPL  208.48   COST  244.23
# 2019-05-03   GOOG  1185.40   AAPL  211.75   COST  244.62

# %%
# Reorganize portfolio data by having a column per symbol
columns = ["drop1", "GOOG Close", "drop2", "AAPL Close", "drop3", "COST Close"]
combined_stocks_df.columns = columns

combined_stocks_df.head()
# Out:
#            drop1  GOOG Close drop2  AAPL Close drop3  COST Close
# Trade DATE
# 2019-05-09  GOOG     1162.38  AAPL      200.72  COST      243.47
# 2019-05-08  GOOG     1166.27  AAPL      202.90  COST      241.34
# 2019-05-07  GOOG     1174.10  AAPL      202.86  COST      240.18
# 2019-05-06  GOOG     1189.39  AAPL      208.48  COST      244.23
# 2019-05-03  GOOG     1185.40  AAPL      211.75  COST      244.62

# %%
filtered_stocks = combined_stocks_df.drop(columns=['drop1', 'drop2', 'drop3'])
filtered_stocks.head()
# Out:
#             GOOG Close  AAPL Close  COST Close
# Trade DATE
# 2019-05-09     1162.38      200.72      243.47
# 2019-05-08     1166.27      202.90      241.34
# 2019-05-07     1174.10      202.86      240.18
# 2019-05-06     1189.39      208.48      244.23
# 2019-05-03     1185.40      211.75      244.62

# %%
# Calculate daily returns
stocks_returns = filtered_stocks.pct_change()
stocks_returns.head()

# Display sample data
# Out:
#             GOOG Close  AAPL Close  COST Close
# Trade DATE
# 2019-05-09         NaN         NaN         NaN
# 2019-05-08    0.003347    0.010861   -0.008749
# 2019-05-07    0.006714   -0.000197   -0.004806
# 2019-05-06    0.013023    0.027704    0.016862
# 2019-05-03   -0.003355    0.015685    0.001597

# %%
# Drop NAs
stocks_returns.dropna(inplace=True)
stocks_returns.head()
# Out:
#             GOOG Close  AAPL Close  COST Close
# Trade DATE
# 2019-05-08    0.003347    0.010861   -0.008749
# 2019-05-07    0.006714   -0.000197   -0.004806
# 2019-05-06    0.013023    0.027704    0.016862
# 2019-05-03   -0.003355    0.015685    0.001597
# 2019-05-02   -0.019226   -0.012279   -0.007890

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights

initial_investment = 1000
weights = [1/3, 1/3, 1/3]
candidate_portfolio_returns = stocks_returns.dot(weights)
candidate_cumulative_returns = (1 + candidate_portfolio_returns).cumprod()
candidate_cumulative_profits = (initial_investment * candidate_cumulative_returns)
candidate_cumulative_profits.plot(figsize=(20,10))


# Calculate portfolio return

# Display sample data
# Out:
# <AxesSubplot:xlabel='Trade DATE'>

# %%
candidate_portfolio_pct = candidate_cumulative_profits.pct_change()
candidate_portfolio_pct.dropna(inplace=True)
candidate_portfolio_pct.head()
# Out:
# Trade DATE
# 2019-05-07    0.000570
# 2019-05-06    0.019196
# 2019-05-03    0.004642
# 2019-05-02   -0.013131
# 2019-05-01    0.002241
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combined_portfolio_df = pd.concat([combined_df, candidate_portfolio_pct], axis="columns", join="inner")
combined_portfolio_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-11                  -0.004717            0.000982
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-11                     0.002624               -0.004125  0.000358
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
#
#               Algo 2  SP500 Returns         0
# 2018-05-11  0.000281      -0.000883 -0.000012
# 2018-05-14  0.001635       0.006889  0.010216
# ...

# %%
columns = ["SOROS FUND MANAGEMENT LLC", "PAULSON & CO.INC.", "TIGER GLOBAL MANAGEMENT LLC", "BERKSHIRE HATHAWAY INC", "Algo 1", "Algo 2", 'SP500 Returns', 'My Portfolio']
combined_portfolio_df.columns = columns
combined_portfolio_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.  \
# 2018-05-11                  -0.004717           0.000982
# 2018-05-14                   0.000000           0.000000
# 2018-05-15                  -0.000726          -0.001409
# 2018-05-16                   0.008637           0.006244
# 2018-05-17                  -0.001955           0.002524
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-11                     0.002624               -0.004125  0.000358
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
#
#               Algo 2  SP500 Returns  My Portfolio
# 2018-05-11  0.000281      -0.000883     -0.000012
# 2018-05-14  0.001635       0.006889      0.010216
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combined_portfolio_df.dropna(inplace=True)
combined_portfolio_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.  \
# 2018-05-11                  -0.004717           0.000982
# 2018-05-14                   0.000000           0.000000
# 2018-05-15                  -0.000726          -0.001409
# 2018-05-16                   0.008637           0.006244
# 2018-05-17                  -0.001955           0.002524
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-11                     0.002624               -0.004125  0.000358
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
#
#               Algo 2  SP500 Returns  My Portfolio
# 2018-05-11  0.000281      -0.000883     -0.000012
# 2018-05-14  0.001635       0.006889      0.010216
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
combined_portfolio_df.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.009234
# PAULSON & CO.INC.              0.007350
# TIGER GLOBAL MANAGEMENT LLC    0.014642
# BERKSHIRE HATHAWAY INC         0.015548
# Algo 1                         0.008419
# Algo 2                         0.008769
# SP500 Returns                  0.009584
# My Portfolio                   0.013426
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
combined_portfolio_df.rolling(window=21).std()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.  \
# 2018-05-11                        NaN                NaN
# 2018-05-14                        NaN                NaN
# 2018-05-15                        NaN                NaN
# 2018-05-16                        NaN                NaN
# 2018-05-17                        NaN                NaN
# ...                               ...                ...
# 2019-04-15                   0.006804           0.006225
# 2019-04-16                   0.006711           0.006224
# 2019-04-17                   0.006773           0.006370
# 2019-04-18                   0.006633           0.006303
# 2019-04-22                   0.005915           0.006400
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-11                          NaN                     NaN       NaN
# 2018-05-14                          NaN                     NaN       NaN
# ...

# %%
# Plot rolling standard deviation
combined_portfolio_df.rolling(window=21).std().plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
combined_df_correlation_stocks = combined_portfolio_df.corr()
# Display de correlation matrix
sns.heatmap(combined_df_correlation_stocks, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
# Calculate covariance of a single portfolio
covariance_myportfolio = combined_portfolio_df['My Portfolio'].rolling(window=60).cov(combined_df['SP500 Returns'])
variance_sp500 = combined_portfolio_df['SP500 Returns'].rolling(window=60).var()

my_beta = covariance_myportfolio / variance_sp500
my_beta.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
sharpe_ratios2 = (combined_portfolio_df.mean() * 252) / (combined_portfolio_df.std() * np.sqrt(252))
sharpe_ratios2
# Out:
# SOROS FUND MANAGEMENT LLC      0.344766
# PAULSON & CO.INC.              0.236041
# TIGER GLOBAL MANAGEMENT LLC   -1.052249
# BERKSHIRE HATHAWAY INC         0.085005
# Algo 1                         1.999866
# Algo 2                         0.009467
# SP500 Returns                 -0.432942
# My Portfolio                  -0.613547
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios2.plot(kind = 'bar', figsize = (20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
print('My portfolio underperforms the S&P500')
# Out:
# My portfolio underperforms the S&P500
